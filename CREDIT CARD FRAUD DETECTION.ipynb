# %% [markdown]
# # CREDIT CARD FRAUD DETECTION

# %% [markdown]
# ## Importing packages

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Loading data

# %%
credit_card_data = pd.read_csv(r"/content/drive/MyDrive/creditcard.csv")

# %%
credit_card_data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %% [markdown]
# ## Dataframe information

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# ## Finding null values count

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Checking for values distribution
# ## Pie chart depicting the distribution

# %%
credit_card_data['Class'].value_counts().plot(kind = 'pie',autopct = '%0.2f%%')
# Out:
# <Axes: ylabel='Class'>

# %%
legit = credit_card_data[credit_card_data['Class'] == 0]
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud = credit_card_data[credit_card_data['Class'] == 1]
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# ## Checking shape before undersampling

# %%
legit.shape
# Out:
# (284315, 31)

# %%
fraud.shape
# Out:
# (492, 31)

# %%
legit.Amount.describe() #describe() will provide all the statistical measures required for further analysis
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean() # groupby function is applied on the dataframes on mean function for comparison of values between those 2 values present in class
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n = 492) #Sample() is used to reduce the normal transaction size to match the fraud transaction so that model accuracy is improved.
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 15217    26576.0  1.159221 -0.118520  0.260527  0.445198 -0.263397 -0.129222
# 29520    35507.0 -1.363456  0.457923  1.372717 -0.196491  1.188633  0.120294
# 63671    50823.0  1.111769 -0.647477 -0.895123 -0.992838  1.525716  3.413101
# 48895    43826.0 -1.471996  0.382024  1.050157  0.477178 -0.151111  0.108983
# 42248    41013.0  1.101251 -0.014725  0.839668  1.349051 -0.231611  0.822125
# ...          ...       ...       ...       ...       ...       ...       ...
# 1170       912.0  1.083003  0.201589  1.497664  2.661922 -0.621256  0.618554
# 170484  120201.0 -2.267247 -3.877322  0.436757  1.720474  2.548160 -2.255347
# 116815   74438.0  1.147305  1.206833 -1.508504  1.529680  0.980275 -1.153621
# 1418      1096.0 -1.253948  0.208497  0.361462 -2.345209  0.601113 -1.463321
# 234004  147790.0  1.852975 -1.179846 -0.337123 -0.350954 -1.270921 -0.448200
#
# ...

# %%
new_credit_data = pd.concat([legit_sample,fraud],axis = 0)
new_credit_data
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 15217    26576.0  1.159221 -0.118520  0.260527  0.445198 -0.263397 -0.129222
# 29520    35507.0 -1.363456  0.457923  1.372717 -0.196491  1.188633  0.120294
# 63671    50823.0  1.111769 -0.647477 -0.895123 -0.992838  1.525716  3.413101
# 48895    43826.0 -1.471996  0.382024  1.050157  0.477178 -0.151111  0.108983
# 42248    41013.0  1.101251 -0.014725  0.839668  1.349051 -0.231611  0.822125
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %% [markdown]
# ## New dataframe value count

# %%
new_credit_data['Class'].value_counts() # Value_counts() is used to find the number of values present for that particular value in a feature After undersampling the values are similar
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
new_credit_data.groupby('Class').mean() #Similarly groupby is again performed on the new dataframe, we have to compare values between the previous dataframe and new dataframe, if it matches then the random sampling is fine.
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      96787.294715  0.032593  0.052676  0.000229 -0.026298  0.170993
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.037874  0.052282  0.048696  0.116460  ... -0.021726 -0.008053
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.034149  0.049299 -0.016356 -0.003697  0.008776  0.012237 -0.007094
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       71.058577
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# ## Model building

# %%
X = new_credit_data.drop('Class',axis = 1)
# 'X' has all the input values to perform the modelling and 'Y' has all the output values to check and compare after the training is completed.
Y = new_credit_data['Class']

# %% [markdown]
# ## Data splitting

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size= 0.2,stratify= Y ,random_state=2)
print(X.shape, X_train.shape, X_test.shape)
#X_train variable is used for fitting the data in modelling and training the data.
#X_test variable is used to access the test results after the training is completed.
#Similarly for Y_train and Y_test.
# Out:
# (984, 30) (787, 30) (197, 30)

# %% [markdown]
# ## Logistic Regression

# %%
Reg_model = LogisticRegression()

# %%
Reg_model.fit(X_train,Y_train) #fitting
# Out:
# LogisticRegression()

# %% [markdown]
# ## Accuracy score

# %%
X_predict_train = Reg_model.predict(X_train)
X_train_accuracy = accuracy_score(X_predict_train,Y_train)

# %%
X_train_accuracy #accuracy score is above 80% it is categorised as accurate result.
# Out:
# 0.9453621346886912

# %%
X_predict_test = Reg_model.predict(X_test)
X_test_accuracy = accuracy_score(X_predict_test,Y_test)

# %%
X_test_accuracy #Since the accuracy score is above 80% it is categorised as accurate result.
# Out:
# 0.9390862944162437
